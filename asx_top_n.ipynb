# %% [markdown]
# <a href="https://colab.research.google.com/github/diabolical-ninja/ceo-diversity/blob/main/asx_top_n.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Return the top N largest companies on the ASX based on market Cap
TOP_N = 15

# %%
url = "https://asx.api.markitdigital.com/asx-research/1.0/companies/directory/file?access_token=83ff96335c2d45a094df02a206a39ff4"
df = pd.read_csv(url)
df.sort_values(by=["Market Cap"], ascending=False, inplace=True)

# %%
asx_top_n = df.iloc[0:TOP_N]
asx_top_n
# Out:
#      ASX code                     Company name Listing date  \
# 307       BHP                BHP GROUP LIMITED   1885-08-13
# 405       CBA  COMMONWEALTH BANK OF AUSTRALIA.   1991-09-12
# 514       CSL                      CSL LIMITED   1994-06-08
# 1301      NAB  NATIONAL AUSTRALIA BANK LIMITED   1962-01-31
# 1999      WBC      WESTPAC BANKING CORPORATION   1970-07-18
# 163       ANZ       ANZ GROUP HOLDINGS LIMITED   1969-09-30
# 1260      MQG          MACQUARIE GROUP LIMITED   2007-11-05
# 764       FMG       FORTESCUE METALS GROUP LTD   1987-03-19
# 2006      WDS        WOODSIDE ENERGY GROUP LTD   1971-11-18
# 2011      WES               WESFARMERS LIMITED   1984-11-15
# 1781      SQ2                       BLOCK INC.   2022-01-20
# 1876      TLS            TELSTRA GROUP LIMITED   1997-11-17
# 1632      RMD                       RESMED INC   1999-11-25
# 2036      WOW         WOOLWORTHS GROUP LIMITED   1993-07-12
# 1846      TCL                 TRANSURBAN GROUP   1996-03-14
#
# ...

# %%
df["Market Cap"]
# Out:
# 0       13324055.0
# 1        9461278.0
# 2       12834989.0
# 3        8358631.0
# 4        6859033.0
#            ...
# 2077    10893269.0
# 2078     6301328.0
# 2079     3653204.0
# 2080    63307088.0
# 2081    10259168.0
# Name: Market Cap, Length: 2082, dtype: float64
